# %%
import pandas as pd
import outlipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 import outlipy
#
# ModuleNotFoundError: No module named 'outlipy'

# %%
import matplotlib.pyplot as plt

# %%
file_path = '../dataset/Final_Outliers_clean_dataset.csv'
df = pd.read_csv(file_path)
df
# Out:
#     User_ID  Loan_ID        City   Age       Job     Education  \
# 0     U2169  L532233      Quetta  39.0     Clerk        Matric
# 1     U4536  L471613    Peshawar  41.0   Manager      Bachelor
# 2     U9628  L354161      Lahore  50.0    Doctor        Matric
# 3     U8765  L650075     Karachi  32.0   Teacher           PhD
# 4     U9245  L501841  Rawalpindi  32.0     Clerk        Matric
# ..      ...      ...         ...   ...       ...           ...
# 855   U6126  L109886      Multan  32.0  Engineer  Intermediate
# 856   U8673  L804220      Quetta  28.0   Manager  Intermediate
# 857   U1597  L505021     Karachi  24.0    Driver           PhD
# 858   U1697  L548765  Faisalabad  32.0    Driver        Matric
# 859   U4571  L629875      Multan  40.0    Driver           PhD
#
#     Marriage_Status  Account_Balance  Loan_Amount  Credit_Score  \
# 0           Married        269967.77     29744.65        554.61
# 1          Divorced        202981.52     26227.40        629.32
# ...

# %%
df.Outli.iqr()
# Out:
#        Age  Account_Balance  Loan_Amount  Credit_Score  Debit_Transactions  \
# 0    False            False        False         False               False
# 1    False            False        False         False               False
# 2    False            False        False         False               False
# 3    False            False        False         False               False
# 4    False            False        False         False               False
# ..     ...              ...          ...           ...                 ...
# 855  False            False        False         False               False
# 856  False            False        False         False               False
# 857  False            False        False         False               False
# 858  False            False        False         False               False
# 859  False            False        False         False               False
#
#      Loan_Duration_Months  Current_Balance
# ...

# %%
df.Outli.iqr().sum()
# Out:
# Age                     4
# Account_Balance         2
# Loan_Amount             5
# Credit_Score            2
# Debit_Transactions      6
# Loan_Duration_Months    0
# Current_Balance         5
# dtype: int64

# %%
iqr = outlipy.IQRDetector(columns=['Age', 'Loan_Amount'])
iqr.detect(df).sum()
# Out:
# Age            4
# Loan_Amount    5
# dtype: int64

# %%
df.Outli.zscore().sum()
# Out:
# Age                     0
# Account_Balance         0
# Loan_Amount             0
# Credit_Score            0
# Debit_Transactions      0
# Loan_Duration_Months    0
# Current_Balance         0
# dtype: int64

# %%
df.Outli.mad().sum()
# Out:
# Age                     3
# Account_Balance         0
# Loan_Amount             0
# Credit_Score            0
# Debit_Transactions      0
# Loan_Duration_Months    0
# Current_Balance         0
# dtype: int64

# %%
df.Outli.percentile(threshold=(0.01, 0.99)).sum()
# Out:
# Age                     15
# Account_Balance         18
# Loan_Amount             18
# Credit_Score            18
# Debit_Transactions      18
# Loan_Duration_Months     0
# Current_Balance         18
# dtype: int64

# %%
df.boxplot(column=['Age'])
plt.show()

# %%
df.boxplot(column=['Account_Balance'])
plt.show()

# %%
df.boxplot(column=['Loan_Amount'])
plt.show()

# %%
df.boxplot(column=['Debit_Transactions'])
plt.show()
